# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = 'credit_risk_data.csv'  # Replace with your file path
df = pd.read_csv(file_path)
df
# Out:
#      Customer_ID  Age  Gender Marital_Status Education_Level  \
# 0           1001   59    Male         Single    Postgraduate
# 1           1002   49    Male        Married    Postgraduate
# 2           1003   35  Female        Married     High School
# 3           1004   63    Male        Married     High School
# 4           1005   28  Female         Single     High School
# ..           ...  ...     ...            ...             ...
# 295         1296   27    Male        Married     High School
# 296         1297   23  Female         Single    Postgraduate
# 297         1298   37  Female        Married     High School
# 298         1299   53    Male        Married     High School
# 299         1300   32    Male         Single     High School
#
#     Employment_Status  Annual_Income  Loan_Amount  Loan_Term_Months  \
# 0            Employed          43236         5726                60
# 1          Unemployed         107955        16362                60
# 2          Unemployed         105514        23297                36
# 3       Self-employed          35358        35448                48
# 4          Unemployed         119713        31172                24
# ..                ...            ...          ...               ...
# 295        Unemployed          34199        31745                24
# 296          Employed         101412        36890                24
# 297     Self-employed          70948        25022                12
# 298     Self-employed          93781         9780                60
# 299          Employed          92750        23311                24
#
#      Interest_Rate  Credit_Score  Number_of_Open_Lines  Debt_to_Income_Ratio  \
# 0             14.1           659                     2                  0.59
# 1              9.2           537                     9                  0.37
# 2              8.1           535                     7                  0.17
# 3             13.0           502                     6                  0.15
# 4              8.5           555                     1                  0.20
# ..             ...           ...                   ...                   ...
# 295           14.3           489                     4                  0.27
# 296            8.3           716                     1                  0.27
# 297           12.8           845                     2                  0.47
# 298           10.1           340                     5                  0.21
# 299           13.6           606                     8                  0.42
#
#      Number_of_Delinquencies  Loan_Default
# 0                          3             0
# 1                          2             0
# 2                          4             0
# 3                          3             0
# 4                          4             0
# ..                       ...           ...
# 295                        0             1
# 296                        0             0
# 297                        3             0
# 298                        3             1
# 299                        0             0
#
# [300 rows x 15 columns]

# %%
# Display first few rows
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#    Customer_ID  Age  Gender Marital_Status Education_Level Employment_Status  \
# 0         1001   59    Male         Single    Postgraduate          Employed
# 1         1002   49    Male        Married    Postgraduate        Unemployed
# 2         1003   35  Female        Married     High School        Unemployed
# 3         1004   63    Male        Married     High School     Self-employed
# 4         1005   28  Female         Single     High School        Unemployed
#
#    Annual_Income  Loan_Amount  Loan_Term_Months  Interest_Rate  Credit_Score  \
# 0          43236         5726                60           14.1           659
# 1         107955        16362                60            9.2           537
# 2         105514        23297                36            8.1           535
# 3          35358        35448                48           13.0           502
# 4         119713        31172                24            8.5           555
#
#    Number_of_Open_Lines  Debt_to_Income_Ratio  Number_of_Delinquencies  \
# 0                     2                  0.59                        3
# 1                     9                  0.37                        2
# 2                     7                  0.17                        4
# 3                     6                  0.15                        3
# 4                     1                  0.20                        4
#
#    Loan_Default
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
# Dataset shape and info
print("\nDataset shape:", df.shape)
print("\nData types and missing values info:")
print(df.info())
# Out:
# Dataset shape: (300, 15)
#
# Data types and missing values info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              300 non-null    int64
#  1   Age                      300 non-null    int64
#  2   Gender                   300 non-null    object
#  3   Marital_Status           300 non-null    object
#  4   Education_Level          300 non-null    object
#  5   Employment_Status        300 non-null    object
#  6   Annual_Income            300 non-null    int64
#  7   Loan_Amount              300 non-null    int64
#  8   Loan_Term_Months         300 non-null    int64
#  9   Interest_Rate            300 non-null    float64
#  10  Credit_Score             300 non-null    int64
#  11  Number_of_Open_Lines     300 non-null    int64
#  12  Debt_to_Income_Ratio     300 non-null    float64
#  13  Number_of_Delinquencies  300 non-null    int64
#  14  Loan_Default             300 non-null    int64
# dtypes: float64(2), int64(9), object(4)
# memory usage: 35.3+ KB
# None

# %%
# Summary statistics for numerical columns
print("\nSummary statistics for numerical features:")
print(df.describe())
# Out:
# Summary statistics for numerical features:
#        Customer_ID         Age  Annual_Income   Loan_Amount  Loan_Term_Months  \
# count   300.000000  300.000000     300.000000    300.000000        300.000000
# mean   1150.500000   42.696667   70691.510000  27091.496667         36.760000
# std      86.746758   13.048328   28278.045153  12401.488032         17.332738
# min    1001.000000   21.000000   20060.000000   5105.000000         12.000000
# 25%    1075.750000   31.000000   47839.000000  16377.750000         24.000000
# 50%    1150.500000   44.000000   71350.000000  26779.000000         36.000000
# 75%    1225.250000   54.000000   95272.500000  37245.000000         48.000000
# max    1300.000000   64.000000  119804.000000  49923.000000         60.000000
#
#        Interest_Rate  Credit_Score  Number_of_Open_Lines  \
# count     300.000000    300.000000            300.000000
# mean       10.470333    574.783333              5.036667
# std         2.630796    159.748244              2.678164
# min         6.100000    307.000000              1.000000
# 25%         8.100000    435.750000              3.000000
# 50%        10.500000    559.500000              5.000000
# 75%        12.800000    713.750000              8.000000
# max        15.000000    847.000000              9.000000
#
#        Debt_to_Income_Ratio  Number_of_Delinquencies  Loan_Default
# count            300.000000               300.000000    300.000000
# mean               0.353067                 2.056667      0.140000
# std                0.147072                 1.414257      0.347567
# min                0.100000                 0.000000      0.000000
# 25%                0.220000                 1.000000      0.000000
# 50%                0.360000                 2.000000      0.000000
# 75%                0.480000                 3.000000      0.000000
# max                0.600000                 4.000000      1.000000

# %%
# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Customer_ID                0
# Age                        0
# Gender                     0
# Marital_Status             0
# Education_Level            0
# Employment_Status          0
# Annual_Income              0
# Loan_Amount                0
# Loan_Term_Months           0
# Interest_Rate              0
# Credit_Score               0
# Number_of_Open_Lines       0
# Debt_to_Income_Ratio       0
# Number_of_Delinquencies    0
# Loan_Default               0
# dtype: int64

# %%
# Distribution plots for numerical features
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in numerical_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Count plots for categorical variables
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x=col)
    plt.title(f'Value counts of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Correlation matrix heatmap
numeric_df = df.select_dtypes(include=['number'])
corr = numeric_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Analyze target variable distribution
plt.figure(figsize=(6,4))
sns.countplot(x='Loan_Default', data=df)
plt.title('Distribution of Loan Default')
plt.show()
